# %%
'''
Overview
this notebook parses all past ufc fight stats when run, it does not include upcoming fights


scrape ufc fight stats
get all event details, name, url, date, location for all ufc events
for each event, get fight details all fights on card
parse each fight to get fight stats of both fighters
'''
# Out:
# '\nOverview\nthis notebook parses all past ufc fight stats when run, it does not include upcoming fights\n\n\nscrape ufc fight stats\nget all event details, name, url, date, location for all ufc events\nfor each event, get fight details all fights on card\nparse each fight to get fight stats of both fighters\n'

# %%
# imports
import pandas as pd
from tqdm.notebook import tqdm_notebook

# import library
import scrape_ufc_stats_library as LIB

# import config
import yaml
config = yaml.safe_load(open('scrape_ufc_stats_config.yaml'))

# %% [markdown]
# # Parse Event Details
# Includes:
# <br>
# Event
# <br>
# URL
# <br>
# Date
# <br>
# Location
# <br>

# %%
# define url to parse
events_url = config['completed_events_all_url']

# %%
# get soup
soup = LIB.get_soup(events_url)

# parse event details
all_event_details_df = LIB.parse_event_details(soup)

# show event details
display(all_event_details_df)

# write event details to file
all_event_details_df.to_csv(config['event_details_file_name'], index=False)
# Out:
#                                       EVENT  \
# 0      UFC Fight Night: Adesanya vs. Imavov
# 1            UFC 311: Makhachev vs. Moicano
# 2         UFC Fight Night: Dern vs. Ribas 2
# 3    UFC Fight Night: Covington vs. Buckley
# 4              UFC 310: Pantoja vs. Asakura
# ..                                      ...
# 713              UFC 6: Clash of the Titans
# 714          UFC 5: The Return of the Beast
# 715          UFC 4: Revenge of the Warriors
# 716               UFC 3: The American Dream
# 717                       UFC 2: No Way Out
#
#                                                    URL                DATE  \
# 0    http://ufcstats.com/event-details/80dbeb1dd5b5...   February 01, 2025
# 1    http://ufcstats.com/event-details/39f68882def7...    January 18, 2025
# 2    http://ufcstats.com/event-details/81ddc98fceb3...    January 11, 2025
# 3    http://ufcstats.com/event-details/72c9c2eadfc3...   December 14, 2024
# 4    http://ufcstats.com/event-details/ad23903ef3af...   December 07, 2024
# ..                                                 ...                 ...
# 713  http://ufcstats.com/event-details/1c3f5e85b59e...       July 14, 1995
# 714  http://ufcstats.com/event-details/dedc3bb440d0...      April 07, 1995
# 715  http://ufcstats.com/event-details/b60391da771d...   December 16, 1994
# 716  http://ufcstats.com/event-details/1a49e0670dfa...  September 09, 1994
# 717  http://ufcstats.com/event-details/a6a9ab5a824e...      March 11, 1994
#
#                            LOCATION
# 0      Riyadh, Riyadh, Saudi Arabia
# 1        Inglewood, California, USA
# 2            Las Vegas, Nevada, USA
# 3               Tampa, Florida, USA
# 4            Las Vegas, Nevada, USA
# ..                              ...
# 713            Casper, Wyoming, USA
# 714  Charlotte, North Carolina, USA
# 715            Tulsa, Oklahoma, USA
# 716  Charlotte, North Carolina, USA
# 717           Denver, Colorado, USA
#
# [718 rows x 4 columns]

# %% [markdown]
# # Parse Fight Details
# Includes:
# <br>
# Event
# <br>
# Bout
# <br>
# URL

# %%
# define list of urls of fights to parse
list_of_events_urls = list(all_event_details_df['URL'])

# %%
# create empty df to store fight details
all_fight_details_df = pd.DataFrame(columns=config['fight_details_column_names'])

# loop through each event and parse fight details
for url in tqdm_notebook(list_of_events_urls):

    # get soup
    soup = LIB.get_soup(url)

    # parse fight links
    fight_details_df = LIB.parse_fight_details(soup)
    
    # concat fight details
    all_fight_details_df = pd.concat([all_fight_details_df, fight_details_df])

# show all fight details
display(all_fight_details_df)

# write fight details to file
all_fight_details_df.to_csv(config['fight_details_file_name'], index=False)
# Out:
#   0%|          | 0/718 [00:00<?, ?it/s]
#                                    EVENT  \
# 0   UFC Fight Night: Adesanya vs. Imavov
# 1   UFC Fight Night: Adesanya vs. Imavov
# 2   UFC Fight Night: Adesanya vs. Imavov
# 3   UFC Fight Night: Adesanya vs. Imavov
# 4   UFC Fight Night: Adesanya vs. Imavov
# ..                                   ...
# 10                     UFC 2: No Way Out
# 11                     UFC 2: No Way Out
# 12                     UFC 2: No Way Out
# 13                     UFC 2: No Way Out
# 14                     UFC 2: No Way Out
#
#                                           BOUT  \
# 0       Nassourdine Imavov vs. Israel Adesanya
# 1             Michael Page vs. Shara Magomedov
# 2   Sergei Pavlovich vs. Jairzinho Rozenstruik
# 3      Vinicius Oliveira vs. Said Nurmagomedov
# 4                    Fares Ziam vs. Mike Davis
# ..                                         ...
# 10           Orlando Wiet vs. Robert Lucarelli
# 11           Frank Hamaker vs. Thaddeus Luster
# 12             Johnny Rhodes vs. David Levicki
# 13                Patrick Smith vs. Ray Wizard
# 14             Scott Morris vs. Sean Daugherty
#
#                                                   URL
# 0   http://ufcstats.com/fight-details/85e79748b75e...
# 1   http://ufcstats.com/fight-details/426e7a3de681...
# 2   http://ufcstats.com/fight-details/3c00f34f20c8...
# 3   http://ufcstats.com/fight-details/70b8dca3addc...
# 4   http://ufcstats.com/fight-details/775788423f5e...
# ..                                                ...
# 10  http://ufcstats.com/fight-details/3b020d4914b4...
# 11  http://ufcstats.com/fight-details/d917c8c7461b...
# 12  http://ufcstats.com/fight-details/ccee020be2e8...
# 13  http://ufcstats.com/fight-details/4b9ae533ccb3...
# 14  http://ufcstats.com/fight-details/4acab67848e7...
#
# [8012 rows x 3 columns]

# %% [markdown]
# # Parse Fight Results and Fight Stats
#
# Fight Results Includes:
# <br>
# Event
# <br>
# Bout
# <br>
# Weightclass
# <br>
# Method
# <br>
# Round
# <br>
# Time
# <br>
# Time Format
# <br>
# Referee
# <br>
# Details
# <br>
#
# Fight Stats Includes:
# <br>
# Event
# <br>
# Bout
# <br>
# Round
# <br>
# Fighter
# <br>
# Kd
# <br>
# Sig.Str.
# <br>
# Sig.Str. %
# <br>
# Total Str.
# <br>
# Td
# <br>
# Td %
# <br>
# Sub.Att
# <br>
# Rev.
# <br>
# Ctrl
# <br>
# Head
# <br>
# Body
# <br>
# Leg
# <br>
# Distance
# <br>
# Clinch
# <br>
# Ground
# <br>

# %%
# define list of urls of fights to parse
list_of_fight_details_urls = list(all_fight_details_df['URL'])

# %%
# create empty df to store fight results
all_fight_results_df = pd.DataFrame(columns=config['fight_results_column_names'])
# create empty df to store fight stats
all_fight_stats_df = pd.DataFrame(columns=config['fight_stats_column_names'])

# loop through each fight and parse fight results and stats
for url in tqdm_notebook(list_of_fight_details_urls):

    # get soup
    soup = LIB.get_soup(url)

    # parse fight results and fight stats
    fight_results_df, fight_stats_df = LIB.parse_organise_fight_results_and_stats(
        soup,
        url,
        config['fight_results_column_names'],
        config['totals_column_names'],
        config['significant_strikes_column_names']
        )

    # check if fight_results_df and fight_stats_df are not None
    if fight_results_df is not None and fight_stats_df is not None:
        # concat fight results
        all_fight_results_df = pd.concat([all_fight_results_df, fight_results_df])
        # concat fight stats
        all_fight_stats_df = pd.concat([all_fight_stats_df, fight_stats_df])
    else:
        print(f"Failed to parse data for URL: {url}")

# show all fight results
display(all_fight_results_df)
# show all fight stats
display(all_fight_stats_df)

# write to file
all_fight_results_df.to_csv(config['fight_results_file_name'], index=False)
# write to file
all_fight_stats_df.to_csv(config['fight_stats_file_name'], index=False)
# Out:
#   0%|          | 0/8012 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 13
#      10 soup = LIB.get_soup(url)
#      12 # parse fight results and fight stats
# ---> 13 fight_results_df, fight_stats_df = LIB.parse_organise_fight_results_and_stats(
#      14     soup,
#      15     url,
#      16     config['fight_results_column_names'],
#      17     config['totals_column_names'],
#      18     config['significant_strikes_column_names']
#      19     )
#      21 # check if fight_results_df and fight_stats_df are not None
#      22 if fight_results_df is not None and fight_stats_df is not None:
#      23     # concat fight results
#
# File ~/nwmissouri/scrape_ufc_stats/scrape_ufc_stats_library.py:436, in parse_organise_fight_results_and_stats(soup, url, fight_results_column_names, totals_column_names, significant_strikes_column_names)
#     415 '''
#     416 parse and organise fight results and fight stats from soup
#     417 this function combines other functions that parse fight results and stats into one
#    (...)
#     430 two dfs for fight results and stats
#     431 '''
#     433 # parse fight results
#     434
#     435 # parase fight results from soup
# --> 436 fight_results = parse_fight_results(soup)
#     437 # append fight url
#     438 fight_results.append('URL:'+url)
#
# File ~/nwmissouri/scrape_ufc_stats/scrape_ufc_stats_library.py:159, in parse_fight_results(soup)
#     156 fight_results = []
#     158 # parse event name
# --> 159 fight_results.append(soup.find('h2', class_='b-content__title').text)
#     161 # parse fighters
#     162 for tag in soup.find_all('a', class_='b-link b-fight-details__person-link'):
#
# AttributeError: 'NoneType' object has no attribute 'text'
